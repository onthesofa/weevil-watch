# %% [markdown]
# ##### Simulate running on a Raspberry Pi

# %% [markdown]
# Clone the repo containing the images and the model

# %%
# !git clone https://github.com/onthesofa/weevil-watch.git
# Out:
# Cloning into 'weevil-watch'...
# remote: Enumerating objects: 1601, done.
# remote: Counting objects: 100% (1194/1194), done.
# remote: Compressing objects: 100% (1173/1173), done.
# remote: Total 1601 (delta 20), reused 1186 (delta 13), pack-reused 407
# Receiving objects: 100% (1601/1601), 125.40 MiB | 34.40 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %% [markdown]
# Move to the directory containing the python scripts and the model

# %%
# %cd /content/weevil-watch/python/deployed
# Out:
# /content/weevil-watch/python/deployed

# %% [markdown]
# Install the libraries containing the functions required to classify images using the model

# %%
# !pip install tflite_support

# %% [markdown]
# Import customised scripts that utilise the classifyer

# %%
from png_classify import *

# %% [markdown]
# Grab an image and classify it, showing confidence.

# %%
from google.colab.patches import cv2_imshow
#img = cv2.imread('/content/weevil-watch/bugs/earwig_199/2022.02.01_18.49..30(2).png', cv2.IMREAD_UNCHANGED)

png = cv2.imread('/content/weevil-watch/bugs/earwig_199/2022.02.01_18.49..30(2).png')

img = sorting_hat('model.tflite', 2, 2, bool(False), png)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F0527E918D0>
